# %% [markdown]
# # Polynomial Fitting Function

# %%
#Importing libraries

#This code has been hidden
# Out:
# Text(0.5, 1.0, 'Given Polynomial with Noisy Data')

# %%
#taking 4 as the order value

#Converting x and y from 2D to 1D Arrays

#Plotting the given Noisy Data

#Using polyfit function to get the coefficients of the polynomial denoted by w

#Getting the 1D polynomial using poly1d function

#Plotting the Expected Polynomial graph

#This code has been hidden

# %%
#Plotting the MSE vs Order
plt.title("Problem 2. Part 2) MSE vs Order m Plot")

#Variable Declaration

#For loop to interate from 1 to 8 values of Order m
for i in range(1,9):
    
    #Using polyfit function to get the coefficients of the polynomial denoted by w
    
    #y_fit = np.polyval(w,x_values);
    #Getting the 1D polynomial using poly1d function

    #Calculate MSE

    #Save MSE and Order Values to be used for plotting later
    
    #Save the least error in a variable and record the Order m value to determine the best m value

#Plotting the MSE vs Order m graph

#This code has been hidden
# Out:
# Problem 2. Part 2) Best choice of Order m is  8

# %%
#Plotting the given Noisy Data vs Polynomial with Noise = 150

#Using polyfit function to get the coefficients of the polynomial denoted by w

#Getting the 1D polynomial using poly1d function

#Plotting the Expected Polynomial graph with the given noise

#This code has been hidden

# %%
#Plotting the given Noisy Data vs Polynomial with noise = 200

#Using polyfit function to get the coefficients of the polynomial denoted by w

#Getting the 1D polynomial using poly1d function

#Plotting the Expected Polynomial graph with the given noise

#This code has been hidden

# %%
#Plotting the given Noisy Data vs Polynomial with noise = 400

#Using polyfit function to get the coefficients of the polynomial denoted by w

#Getting the 1D polynomial using poly1d function

#Plotting the Expected Polynomial graph with the given noise

#This code has been hidden

# %%
#Plotting the given Noisy Data vs Polynomial with Noise Scale = 600

#Using polyfit function to get the coefficients of the polynomial denoted by w

#Getting the 1D polynomial using poly1d function

#Plotting the Expected Polynomial graph with the given Noise Scale

#This code has been hidden

# %%
#Plotting the given Noisy Data vs Polynomial with Noise Scale = 1000

#Using polyfit function to get the coefficients of the polynomial denoted by w

#Getting the 1D polynomial using poly1d function

#Plotting the Expected Polynomial graph with the given Noise Scale

#This code has been hidden

# %%
#This code has been hidden
# Out:
# Problem 2. Part 3) OBSERVATION: Increasing Noise Scale from 100 to 1000 has decreased the accuracy of the predicted polynomial and the best choice of m = 8 that was observed earlier. The graph is more scattered and the result of the polyfit function is less accurate.

# %%
#Plotting the given Noisy Data vs Polynomial with Number of Samples = 40

#Converting x and y from 2D to 1D Arrays

#Plotting the given Noisy Data

#taking best m as the order value

#Using polyfit function to get the coefficients of the polynomial denoted by w

#Getting the 1D polynomial using poly1d function

#Plotting the Expected Polynomial graph

#This code has been hidden

# %%
#Plotting the given Noisy Data vs Polynomial with Number of Samples = 30

#Converting x and y from 2D to 1D Arrays

#Plotting the given Noisy Data

#taking best m as the order value

#Using polyfit function to get the coefficients of the polynomial denoted by w

#Getting the 1D polynomial using poly1d function

#Plotting the Expected Polynomial graph

#This code has been hidden

# %%
#Plotting the given Noisy Data vs Polynomial with Number of Samples = 20

#Converting x and y from 2D to 1D Arrays

#Plotting the given Noisy Data

#taking best m as the order value

#Using polyfit function to get the coefficients of the polynomial denoted by w

#Getting the 1D polynomial using poly1d function

#Plotting the Expected Polynomial graph

#This code has been hidden

# %%
#Plotting the given Noisy Data vs Polynomial with Number of Samples = 10

#Converting x and y from 2D to 1D Arrays

#Plotting the given Noisy Data

#taking best m as the order value

#Using polyfit function to get the coefficients of the polynomial denoted by w

#Getting the 1D polynomial using poly1d function

#Plotting the Expected Polynomial graph

#This code has been hidden

# %%
#This code has been hidden
# Out:
# Problem 2. Part 4) OBSERVATION: Reducing the number of samples from 50 to 10 has decreased the accuracy of the predicted polynomial and best choice of m = 8 that was observed earlier. The graph is more scattered and the result of the polyfit function is less accurate. It will require a lesser order polynomial to fit the dataset.
