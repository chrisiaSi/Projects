# %% [markdown]
# # Genetic Algorithm Implementation

# %% [markdown]
# ### Step1: The Original Noisy Data

# %%
#Import Libraries
# Out:
# Text(0.5, 1.0, 'Given Polynomial with Noisy Data')

# %% [markdown]
# ### Step2: Polynomial obtained in Homework #1

# %%
#taking 3 as the order value
m = 3

#Converting x and y from 2D to 1D Arrays

#Plotting the given Noisy Data

#Using polyfit function to get the coefficients of the polynomial denoted by w

#Getting the 1D polynomial using poly1d function

#Plotting the Expected Polynomial graph

#Code has been hidden
# Out:
#        3         2
# 1.026 x + 15.71 x + 10.11 x - 22.56

# %% [markdown]
# ### Step3: Genetic algorithm to solve the polynomial fitting problem in Homework #1 using MUTATION and CROSSOVER

# %%
#Split test and train data
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x.squeeze(), y.squeeze(), test_size=0.20, random_state=1)

# %%
#Define polyfitGA function
def polyFitGA(iter=500, mutationRate=0.02, crossoverRate=2):

    # Generate New Chromosomes
    # Mutation

  # Pick Best Chromosome

# %%
#Define crossover function with male and female as parameters
def crossover_func(male, female):

# %%
# Perform crossover

# Perform mutation

# update population

#Code has been hidden

# %%
Best = sorted(pop, key=lambda x: x[4])[0:10]

# %%
# Polynomial fitting using Polyfit function

# %%
# Plotting all the graphs in the same plot.

# %% [markdown]
# ### OBSERVATION: We can observe that polyfit function fits the curve better than the Genetic Algorithm. Genetic Algorithm may provide better results if the parameters were tweaked. For example, if the generations were increased.
